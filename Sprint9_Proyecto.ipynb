# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
#  <font size="5"> **Descripción del proyecto:** </font>
#
# Lo has hecho de maravilla en el curso de TripleTen y te han ofrecido hacer prácticas en el departamento de analítica de Showz, una empresa de venta de entradas de eventos. Tu primera tarea es ayudar a optimizar los gastos de marketing.
#
# **Cuentas con:**
#
# - registros del servidor con datos sobre las visitas a Showz desde enero de 2017 hasta diciembre de 2018;
# - un archivo con los pedidos en este periodo;
# - estadísticas de gastos de marketing.
#
# **Lo que vas a investigar:**
#
# - cómo los clientes usan el servicio;
# - cuándo empiezan a comprar;
# - cuánto dinero aporta cada cliente a la compañía;
# - cuándo los ingresos cubren el costo de adquisición de los clientes.

# %% [markdown]
#   **Table of contents**<a id='toc0_'></a>
#     **1.** [Importación de librerias](#toc1_)
#     **2.** [Carga de datos](#toc2_)
#     **3.** [Exploración de datos](#toc3_)
#         **3.1** [Dataframe de Visitas](#toc4_)
#         **3.2** [Dataframe de Ordenes](#toc5_)
#         **3.3** [Datafame de Costos](#toc6_)
#     **4.** [Analisis profundo de datos](#toc7_)
#         **4.1** [Visitas](#toc8_)
#         **4.2** [Ventas](#toc9_)
#         **4.3** [Marketing](#toc10_)
#     - [Conclusiones finales](#toc11_)

# %% [markdown]
# # <a id='toc1_'></a>[Importación de librerias](#toc1_)

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # <a id='toc2_'></a>[Carga de datos](#toc2_)

# %%
# Vamos a cargar correctamente nuestros datasets
visits_df = pd.read_csv("/datasets/visits_log_us.csv")
orders_df = pd.read_csv("/datasets/orders_log_us.csv")
costs_df = pd.read_csv("/datasets/costs_us.csv")

# %% [markdown]
# # <a id='toc3_'></a>[Exploración de datos](#toc3_)

# %% [markdown]
# - Primero que nada, vamos a ver como se comportan los datos de los diferentes DataFrames y analizar si presentan algun tipo de error

# %% [markdown]
# # <a id='toc4_'></a>[Dataframe de Visitas](#toc4_)

# %%
# Empecemos con el primer df de visitas
visits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Device     359400 non-null  object
#  1   End Ts     359400 non-null  object
#  2   Source Id  359400 non-null  int64
#  3   Start Ts   359400 non-null  object
#  4   Uid        359400 non-null  uint64
# dtypes: int64(1), object(3), uint64(1)
# memory usage: 13.7+ MB

# %% [markdown]
# Podemos apreciar que las columnas "End Ts", "Start Ts", "Device" y "Uid" tienen el tipo de datos incorrecto. Ademas, se encuentran escritos con mayusculas, lo cual no es muy recomendable a la hora de realizar los análisis.
#
# **Lo vamos a corregir a continuación.**

# %%
visits_df['End Ts']= pd.to_datetime(visits_df['End Ts'])
visits_df['Start Ts']= pd.to_datetime(visits_df['Start Ts'])
visits_df['Device']= visits_df['Device'].astype('category')
visits_df['Uid']= visits_df['Uid'].astype('int')

# Confirmamos si se corrigieron los tipos de datos
visits_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Device     359400 non-null  category
#  1   End Ts     359400 non-null  datetime64[ns]
#  2   Source Id  359400 non-null  int64
#  3   Start Ts   359400 non-null  datetime64[ns]
#  4   Uid        359400 non-null  int64
# dtypes: category(1), datetime64[ns](2), int64(2)
# memory usage: 11.3 MB

# %%
# Ahora vamos a modificar los nombres de las columnas para que esten escritas correctamente.

visits_new_columns = {
    'Device': 'device',
    'End Ts': 'end_ts',
    'Source Id': 'source_id',
    'Start Ts': 'start_ts',
    'Uid': 'uid'
}

visits_df.rename(columns=visits_new_columns, inplace=True)

# Corroboramos que se hayan actualizado los nombres correctamente
print(visits_df.columns)
print()
visits_df.info()
# Out:
# Index(['device', 'end_ts', 'source_id', 'start_ts', 'uid'], dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359400 entries, 0 to 359399
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   device     359400 non-null  category
#  1   end_ts     359400 non-null  datetime64[ns]
#  2   source_id  359400 non-null  int64
#  3   start_ts   359400 non-null  datetime64[ns]
#  4   uid        359400 non-null  int64
# dtypes: category(1), datetime64[ns](2), int64(2)
# memory usage: 11.3 MB

# %%
# Ahora vamos a ver como se comportan los datos de la columna de "uid"
visits_df.head(10)
# Out:
#     device              end_ts  source_id            start_ts  \
# 0    touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1  desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2    touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4  desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
# 5  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
# 6  desktop 2018-01-30 12:09:00          1 2018-01-30 11:13:00
# 7    touch 2017-11-05 15:15:00          3 2017-11-05 15:14:00
# 8  desktop 2017-07-19 10:44:00          3 2017-07-19 10:41:00
# 9  desktop 2017-11-08 13:43:00          5 2017-11-08 13:42:00
#
#                    uid
# 0 -1567487796173571554
# 1   104060357244891740
# 2  7459035603376831527
# 3 -2272063814375341402
# 4 -8477049253672870448
# 5 -2439207879601176229
# 6  6661610529277171451
# 7 -7022878382855011304
# 8  2987360259350925644
# 9  1289240080042562063

# %% [markdown]
# Podemos observar que hay ciertos datos que cuentan con un signo negativo ("-"), esto nos puede perjudicar en nuestro análisis ya que necesitamos que los datos sean unicos.
#
# **Lo vamos a corregir a continuación.**

# %%
# Verifiquemos cuantos datos en total cuentan con el signo negativo en nuestro DF

filtered_visits = visits_df["uid"].astype(str)
filtered_visits[filtered_visits.str.startswith("-")]
# Out:
# 0         -1567487796173571554
# 3         -2272063814375341402
# 4         -8477049253672870448
# 5         -2439207879601176229
# 7         -7022878382855011304
#                   ...
# 359395      -83452591748064077
# 359396      -75912520690432030
# 359397      -59446488208803322
# 359398      -58127129084775131
# 359399      -50615139655002057
# Name: uid, Length: 179803, dtype: object

# %% [markdown]
# Como podemos observar, son demasiados datos los que cuentan con el signo negativo lo cual no podremos ignorar.

# %%
# A continuación utilizaremos un metodo para poder eliminar el signo negativo de todos los datos

visits_df['uid']= visits_df['uid'].abs()
visits_df.head(10)
# Out:
#     device              end_ts  source_id            start_ts  \
# 0    touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1  desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2    touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4  desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
# 5  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
# 6  desktop 2018-01-30 12:09:00          1 2018-01-30 11:13:00
# 7    touch 2017-11-05 15:15:00          3 2017-11-05 15:14:00
# 8  desktop 2017-07-19 10:44:00          3 2017-07-19 10:41:00
# 9  desktop 2017-11-08 13:43:00          5 2017-11-08 13:42:00
#
#                    uid
# 0  1567487796173571554
# 1   104060357244891740
# 2  7459035603376831527
# 3  2272063814375341402
# 4  8477049253672870448
# 5  2439207879601176229
# 6  6661610529277171451
# 7  7022878382855011304
# 8  2987360259350925644
# 9  1289240080042562063

# %% [markdown]
# Este DataFrame presento tipos de datos incorrectos en sus columnas, utilización de mayusculas en sus nombres y ademas presento un signo negativo en los datos enteros de la columna "uid". Todo esto fue corregido correctamente.
#
# **Ahora pasemos al siguiente DataFrame**

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente trabajo al corregir tipos de datos, estandarizar nombres de columnas y solucionar valores negativos en la columna uid. Estas acciones mejoran la consistencia y calidad del DataFrame, facilitando futuros análisis.
#
# </div>

# %% [markdown]
# # <a id='toc5_'></a>[Dataframe de Ordenes](#toc5_)

# %%
# Veamos como se comporta el segundo df de ordenes
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Buy Ts   50415 non-null  object
#  1   Revenue  50415 non-null  float64
#  2   Uid      50415 non-null  uint64
# dtypes: float64(1), object(1), uint64(1)
# memory usage: 1.2+ MB

# %% [markdown]
# Podemos apreciar que las columnas "Buy Ts" y "Uid" tienen el tipo de datos incorrecto. Ademas, se encuentran escritos con mayusculas y con espacios en todas las columnas del DF.
#
# **Lo vamos a corregir a continuación.**

# %%
orders_df['Buy Ts']= pd.to_datetime(orders_df['Buy Ts'])
orders_df['Uid']= orders_df['Uid'].astype('int')

# Confirmamos si se corrigieron los tipos de datos
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Buy Ts   50415 non-null  datetime64[ns]
#  1   Revenue  50415 non-null  float64
#  2   Uid      50415 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.2 MB

# %%
# Ahora vamos a modificar los nombres de las columnas para que esten escritas correctamente.

orders_new_columns = {
    'Buy Ts': 'buy_ts',
    'Revenue': 'revenue',
    'Uid': 'uid',
}

orders_df.rename(columns=orders_new_columns, inplace=True)

# Corroboramos que se hayan actualizado los nombres correctamente
print(orders_df.columns)
print()
orders_df.info()
# Out:
# Index(['buy_ts', 'revenue', 'uid'], dtype='object')
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50415 entries, 0 to 50414
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   buy_ts   50415 non-null  datetime64[ns]
#  1   revenue  50415 non-null  float64
#  2   uid      50415 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.2 MB

# %%
# Ahora vamos a ver como se comportan los datos de la columna de "uid"
orders_df.head(10)
# Out:
#                buy_ts  revenue                  uid
# 0 2017-06-01 00:10:00    17.00 -8117441949118824122
# 1 2017-06-01 00:25:00     0.55 -6819486350016644169
# 2 2017-06-01 00:27:00     0.37  -543063512405337772
# 3 2017-06-01 00:29:00     0.55 -2337504304266998611
# 4 2017-06-01 07:58:00     0.37 -4246138198461172166
# 5 2017-06-01 08:43:00     0.18 -8044349643513138295
# 6 2017-06-01 08:54:00     1.83 -5982117330579862978
# 7 2017-06-01 09:22:00     1.22  3644482766749211722
# 8 2017-06-01 09:22:00     3.30  -904673363739710137
# 9 2017-06-01 09:23:00     0.37  1074355127080856382

# %% [markdown]
# Podemos observar que de nuevo hay ciertos datos que cuentan con un signo negativo ("-"). Es importante que no presente este signo negativo en nuestros datos, no es optimo.
#
# **Lo vamos a corregir a continuación.**

# %%
# Verifiquemos cuantos datos en total cuentan con el signo negativo en nuestro DF

filtered_orders = orders_df["uid"].astype(str)
filtered_orders[filtered_orders.str.startswith("-")]
# Out:
# 0        -8117441949118824122
# 1        -6819486350016644169
# 2         -543063512405337772
# 3        -2337504304266998611
# 4        -4246138198461172166
#                  ...
# 50406    -5325290768098931952
# 50407    -2870399464313825909
# 50408    -2592351495200723586
# 50410    -6150117474222222992
# 50411    -7077103708202075640
# Name: uid, Length: 24905, dtype: object

# %% [markdown]
# Como podemos observar, son demasiados datos los que cuentan con el signo negativo lo cual no podremos ignorar.

# %%
# A continuación utilizaremos un metodo para poder eliminar el signo negativo de todos los datos

orders_df['uid']= orders_df['uid'].abs()
orders_df.head(10)
# Out:
#                buy_ts  revenue                  uid
# 0 2017-06-01 00:10:00    17.00  8117441949118824122
# 1 2017-06-01 00:25:00     0.55  6819486350016644169
# 2 2017-06-01 00:27:00     0.37   543063512405337772
# 3 2017-06-01 00:29:00     0.55  2337504304266998611
# 4 2017-06-01 07:58:00     0.37  4246138198461172166
# 5 2017-06-01 08:43:00     0.18  8044349643513138295
# 6 2017-06-01 08:54:00     1.83  5982117330579862978
# 7 2017-06-01 09:22:00     1.22  3644482766749211722
# 8 2017-06-01 09:22:00     3.30   904673363739710137
# 9 2017-06-01 09:23:00     0.37  1074355127080856382

# %%
# Ahora veamos como se comporta los datos de la columna de revenue
orders_df["revenue"].head(10)
# Out:
# 0    17.00
# 1     0.55
# 2     0.37
# 3     0.55
# 4     0.37
# 5     0.18
# 6     1.83
# 7     1.22
# 8     3.30
# 9     0.37
# Name: revenue, dtype: float64

# %% [markdown]
# Notamos que presenta algunos numeros con 0 y decimal. Vamos a hacer una busqueda especifica para ver si presenta valores en 0 total.

# %%
# Vamos a verificar si cuenta con valores en 0 y si es asi cuantos tiene en total

filtered_revenue_orders = orders_df[orders_df["revenue"]== 0]
print(filtered_revenue_orders.head(10))
print()

print("Cantidad de valores en cero:", len(filtered_revenue_orders))
# Out:
#                   buy_ts  revenue                  uid
# 1802 2017-06-22 18:19:00      0.0  1416215280783008533
# 2787 2017-07-07 15:54:00      0.0  8165319053293938683
# 4783 2017-08-02 14:54:00      0.0   184148767273119549
# 5095 2017-08-09 14:48:00      0.0  5603453646174104178
# 5863 2017-08-23 13:43:00      0.0  5603453646174104178
# 6393 2017-08-30 16:30:00      0.0  5603453646174104178
# 6995 2017-09-06 13:57:00      0.0  5603453646174104178
# 7104 2017-09-07 14:37:00      0.0  5603453646174104178
# 7488 2017-09-11 16:53:00      0.0  8276858283244483808
# 8160 2017-09-18 16:49:00      0.0  2883839899480223178
#
# Cantidad de valores en cero: 51

# %% [markdown]
# Como podemos observar, en nuestros datos contamos con 51 valores en cero. Vamos a proceder a eliminarlos ya que son valores atipicos que no podemos tener en nuestros análisis.

# %%
# Vamos a descartar estos valores en cero
orders_df= orders_df[orders_df['revenue'] != 0]

# Revisemos que se eliminaron correctamente
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50364 entries, 0 to 50414
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   buy_ts   50364 non-null  datetime64[ns]
#  1   revenue  50364 non-null  float64
#  2   uid      50364 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.5 MB

# %% [markdown]
# Este DataFrame presento tipos de datos incorrectos en sus columnas, utilización de mayusculas en sus nombres, ademas presento un signo negativo en los datos enteros de la columna "uid" y por ultimo, se encontraron algunos valores en cero lo cual todo esto fue corregido correctamente.
#
# **Ahora pasemos al siguiente DataFrame**

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Muy buen trabajo al corregir los tipos de datos, estandarizar nombres de columnas, eliminar valores negativos en uid y filtrar valores en cero en revenue. Estas acciones garantizan un DataFrame limpio y listo para un análisis preciso.
#
# </div>

# %% [markdown]
# # <a id='toc6_'></a>[Dataframe de Costos](#toc6_)

# %%
# Veamos como se comporta el tercer df de costos
costs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source_id  2542 non-null   int64
#  1   dt         2542 non-null   object
#  2   costs      2542 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 59.7+ KB

# %% [markdown]
# Podemos observar que este DataFrame cuenta con sus nombres de columnas correctos en minusculas y con guiones bajos. Nada mas seria corregir el tipo de dato de la columna "dt".
#
# **Lo vamos a corregir a continuación.**

# %%
costs_df['dt']= pd.to_datetime(costs_df['dt'])

# Confirmamos si se corrigieron los tipos de datos
costs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2542 entries, 0 to 2541
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   source_id  2542 non-null   int64
#  1   dt         2542 non-null   datetime64[ns]
#  2   costs      2542 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 59.7 KB

# %%
# Vamos a buscar valores atipicos utilizando el metodo "describe" en nuestro DataFrame

costs_df.describe()
# Out:
#          source_id        costs
# count  2542.000000  2542.000000
# mean      4.857199   129.477427
# std       3.181581   156.296628
# min       1.000000     0.540000
# 25%       2.000000    21.945000
# 50%       4.000000    77.295000
# 75%       9.000000   170.065000
# max      10.000000  1788.280000

# %% [markdown]
# Como podemos observar, nada más se corregio el tipo de dato de la columna "dt", ya que no presenta ningun otro valor atipico que pueda perjudicarnos más adelante en nuestros procesos de análisis. Este DataFrame a comparación de los demas estaba más correcto a lo que buscamos nosotros.
#
# Podemos observar que cuenta con una media entre 4 y 5 fuentes que se utilizan para atraer clientes y los costos estan entre los 129 hasta el maximo de 1788. Entraremos en mayor detalle más adelante para contestar las preguntas objetivos que nos fueron otorgadas.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen trabajo al corregir el tipo de dato en la columna dt y validar que el DataFrame no contiene valores atípicos significativos. Este enfoque demuestra una revisión eficiente y asegura que los datos estén listos para su análisis posterior.
#
# </div>

# %% [markdown]
# # <a id='toc7_'></a>[Análisis profundo de datos](#toc7_)

# %% [markdown]
# Una vez que hayamos limpiado nuestros datos de los DataFrames que vamos a utilizar, ya podemos comenzar con el proceso de análisis profundo en donde nos enfocaremos a responder las diferentes preguntas establecidas en este proyecto.

# %% [markdown]
# # <a id='toc8_'></a>[Visitas](#toc8_)

# %% [markdown]
# En esta sección se nos pide responder correctamente las siguientes preguntas:
# - ¿Cuántas personas lo usan cada día, semana y mes?
# - ¿Cuántas sesiones hay por día? (Un usuario puede tener más de una sesión).
# - ¿Cuál es la duración de cada sesión?
# - ¿Con qué frecuencia los usuarios regresan?

# %%
# Vamos a crear las nuevas columnas con datos por dia, semana, mes y año que necesitaremos para nuestro análsis.
visits_df['session_year']  = visits_df['start_ts'].dt.year
visits_df['session_month'] = visits_df['start_ts'].dt.month
visits_df['session_week']  = visits_df['start_ts'].dt.week
visits_df['session_date'] = visits_df['start_ts'].dt.date

visits_df.head(10)
# Out:
#     device              end_ts  source_id            start_ts  \
# 0    touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1  desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2    touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4  desktop 2017-12-27 14:06:00          3 2017-12-27 14:06:00
# 5  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
# 6  desktop 2018-01-30 12:09:00          1 2018-01-30 11:13:00
# 7    touch 2017-11-05 15:15:00          3 2017-11-05 15:14:00
# 8  desktop 2017-07-19 10:44:00          3 2017-07-19 10:41:00
# 9  desktop 2017-11-08 13:43:00          5 2017-11-08 13:42:00
#
#                    uid  session_year  session_month  session_week session_date
# 0  1567487796173571554          2017             12            51   2017-12-20
# 1   104060357244891740          2018              2             8   2018-02-19
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente preparación al agregar columnas derivadas para días, semanas, meses y años. Estas nuevas variables facilitarán el análisis temporal y la respuesta a las preguntas clave del proyecto.
#
# </div>

# %% [markdown]
#  <font size="4"> **¿Cuántas personas lo usan cada día, semana y mes?** </font>

# %%
# Para responder esta pregunta, debemos realizar los calculos con las formulas correctas para descubrir la cantidad de personas que usan la aplicación.

dau_total = visits_df.groupby('session_date').agg({'uid': 'nunique'}).mean()
wau_total = visits_df.groupby(['session_year', 'session_week']).agg({'uid': 'nunique'}).mean()
mau_total = (visits_df.groupby(['session_year', 'session_month']).agg({'uid': 'nunique'}).mean())

print('Número de usuarios activos diarios (unicos): ', dau_total)
print()
print('Número de usuarios activos semanales: ', wau_total)
print()
print('Número de usuarios activos mensuales: ', mau_total)
# Out:
# Número de usuarios activos diarios (unicos):  uid    907.991758
# dtype: float64
#
# Número de usuarios activos semanales:  uid    5716.245283
# dtype: float64
#
# Número de usuarios activos mensuales:  uid    23228.416667
# dtype: float64

# %% [markdown]
# Gracias a los calculos que realizamos descubrimos que 908 fueron los usuarios que utilizan el servicio diaramente, 5,716 la usan semanalmente y 23228 la usan mensualmente. Se podria considerar una buena cantidad de usuarios, vamos a seguir analizando.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Muy bien al calcular los usuarios activos diarios, semanales y mensuales utilizando agrupaciones y agregaciones adecuadas. Presentar los promedios brinda un panorama claro del uso del servicio en diferentes períodos.
#
# </div>

# %% [markdown]
#  <font size="4"> **¿Cuántas sesiones hay por día? (Un usuario puede tener más de una sesión).** </font>

# %%
# Para descrubrir esta información, primero necesitamos agrupar los datos con las columnas "year" y "date" para encontrar el numero de usuarios unicos del servicio.

sessions_per_user = visits_df.groupby(['session_year', 'session_date']).agg(
    {'uid': ['count', 'nunique']}
)

# Vamos a cambiar los nombres de las columnas para que se entiendan mejor 

sessions_per_user.columns = ['n_sessions', 'n_users']

# Aplicaremos la formula para encontrar la cantidad de sesiones por usuario diario

sessions_per_user['sessions_per_user'] = (
    sessions_per_user['n_sessions'] / sessions_per_user['n_users']
)
sessions_per_user= sessions_per_user.reset_index()
print(sessions_per_user)
# Out:
#      session_year session_date  n_sessions  n_users  sessions_per_user
# 0            2017   2017-06-01         664      605           1.097521
# 1            2017   2017-06-02         658      608           1.082237
# 2            2017   2017-06-03         477      445           1.071910
# 3            2017   2017-06-04         510      476           1.071429
# 4            2017   2017-06-05         893      820           1.089024
# ..            ...          ...         ...      ...                ...
# 359          2018   2018-05-27         672      620           1.083871
# 360          2018   2018-05-28        1156     1039           1.112608
# 361          2018   2018-05-29        1035      948           1.091772
# 362          2018   2018-05-30        1410     1289           1.093871
# 363          2018   2018-05-31        2256     1997           1.129695
#
# [364 rows x 5 columns]

# %%
# Una vez teniendo los resultados, vamos a crear un histograma para poder observar a detalle la distribución del numero de sesiones de usuarios que se tiene para cada dia.

sessions_per_user['sessions_per_user'].plot(kind= 'hist',
                                        bins= 100,
                                       title= 'Número de sesiones por usuario',
                                       figsize= (12, 8),
                                       color= 'blue'
                                       )
plt.xlabel('Número de sesiones diarias')
plt.ylabel('Frecuencia')
plt.show()

# %%
# Ahora realizamos el mismo procedimiento pero para graficar las sesiones de usuarios para cada mes.

sessions_per_user.plot(x = 'session_date',
                  y= 'sessions_per_user',
                  kind= 'line',
                  figsize= [12,8],
                  fontsize= 12,
                  rot= 100,
                  color= 'green',
                  legend=False     
                       )
plt.title('Numero de sesiones por usuarios mensuales', fontsize=15)
plt.xlabel('Mes', fontsize=15)
plt.ylabel('Cantidad promedio de sesiones', fontsize=15)


plt.show()

# %% [markdown]
# Como podemos observar en nuestro histograma, contamos con un numero basico y normal de usuarios por dia que en este caso el promedio es 1. Y en el grafico mensual de usuarios, podemos observar que el mes que más destaca es el de Diciembre a comparación de los demas meses.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen trabajo al calcular el promedio de sesiones por usuario y representarlo visualmente mediante un histograma y una gráfica temporal. Esto permite identificar patrones diarios y mensuales, destacando eficientemente períodos clave como diciembre.
#
# </div>

# %% [markdown]
#  <font size="4"> **¿Cuál es la duración de cada sesión?** </font>

# %%
# Primero necesitamos crear una nueva columna que se llamara "session_duration_sec" y aplicaremos formulas para encontrar la duración de cada sesión.
visits_df['session_duration_sec'] = (visits_df['end_ts'] - visits_df['start_ts']).dt.seconds
print(visits_df['session_duration_sec'].mean())
# Out:
# 643.506488592098

# %%
# Teniendo el resultado, vamos a crear un histograma para poder visualizar mejor los datos.
visits_df['session_duration_sec'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
# Notamos que los datos no son normales, asi que vamos a calcular la moda.
asl= visits_df['session_duration_sec'].mode()
print(asl)
# Out:
# 0    60
# dtype: int64

# %%
# Teniendo la moda, utilizamos el metodo describe() para poder tener una vista más clara y completa de como se comportan los datos en nuestra columna
visits_df['session_duration_sec'].describe()
# Out:
# count    359400.000000
# mean        643.506489
# std        1016.334786
# min           0.000000
# 25%         120.000000
# 50%         300.000000
# 75%         840.000000
# max       84480.000000
# Name: session_duration_sec, dtype: float64

# %% [markdown]
# Como pudimos observar, al principio el histograma nos arrojo valores atipicos, por eso se decidio calcular la moda. El describe nos dice que el numero maximo es de 84480 segundos, lo cual en minutos son 1408, lo cual viene siendo practicamente un dia. En cambio, la moda nos arrojo que la duración promedio de un usuario es de 60 segundos, lo que viene siendo 1 minuto practicamente. Ese resultado ya es más normal.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente enfoque al calcular la duración de las sesiones y analizar los valores atípicos con histogramas y estadísticas descriptivas. Usar la moda como medida representativa fue una decisión acertada para interpretar datos con sesgo.
#
# </div>

# %% [markdown]
#  <font size="4"> **¿Con qué frecuencia los usuarios regresan?** </font>

# %%
# Para calcular la frecuencia, necesitamos utilizar las formulas con "sticky"

sticky_wau= dau_total/wau_total * 100
print(sticky_wau)
sticky_mau= dau_total/mau_total * 100
print(sticky_mau)
# Out:
# uid    15.884409
# dtype: float64
# uid    3.90897
# dtype: float64

# %% [markdown]
# Como podemos observar:
# - sticky_wau: Nos dio como resultado 15.88%, que vienen siento los usuarios que usan el servicio en una semana tambien la usan diariamente.
#
# - sticky_mau: Nos dio como resultado 3.90%, que vienen siendo los usuarios que usan el servicio en un mes y tambien la usan diariamente.
#
# Contamos con un compromiso adecuado de es del 16%, el cual es optimo y sugiere que existen usuarios que se encuentran utilizando el servicio diariamente.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen trabajo al calcular los indicadores de compromiso sticky_wau y sticky_mau. Estos resultados ofrecen una visión clara sobre la frecuencia de uso del servicio y reflejan un nivel de compromiso adecuado por parte de los usuarios.
#
# </div>

# %% [markdown]
# # <a id='toc9_'></a>[Ventas](#toc9_)

# %% [markdown]
# En esta sección se nos pide responder correctamente las siguientes preguntas:
# - ¿Cuándo empieza la gente a comprar? (En el análisis de KPI, generalmente nos interesa saber el tiempo que transcurre entre el registro y la conversión, es decir, cuando el usuario se convierte en cliente. Por ejemplo, si el registro y la primera compra ocurren el mismo día, el usuario podría caer en la categoría Conversion 0d. Si la primera compra ocurre al día siguiente, será Conversion 1d. Puedes usar cualquier enfoque que te permita comparar las conversiones de diferentes cohortes para que puedas determinar qué cohorte o canal de marketing es más efectivo.)
# - ¿Cuántos pedidos hacen durante un período de tiempo dado?
# - ¿Cuál es el tamaño promedio de compra?
# - ¿Cuánto dinero traen? (LTV)

# %%
# Aqui tenemos nuestro DataFrame de Ventas
orders_df.head(10)
# Out:
#                buy_ts  revenue                  uid
# 0 2017-06-01 00:10:00    17.00  8117441949118824122
# 1 2017-06-01 00:25:00     0.55  6819486350016644169
# 2 2017-06-01 00:27:00     0.37   543063512405337772
# 3 2017-06-01 00:29:00     0.55  2337504304266998611
# 4 2017-06-01 07:58:00     0.37  4246138198461172166
# 5 2017-06-01 08:43:00     0.18  8044349643513138295
# 6 2017-06-01 08:54:00     1.83  5982117330579862978
# 7 2017-06-01 09:22:00     1.22  3644482766749211722
# 8 2017-06-01 09:22:00     3.30   904673363739710137
# 9 2017-06-01 09:23:00     0.37  1074355127080856382

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen inicio al presentar claramente las preguntas clave para esta sección y asegurarte de que el DataFrame de ventas esté preparado para responderlas. Este enfoque estructurado facilitará un análisis efectivo.
#
# </div>

# %% [markdown]
#  <font size="4"> **¿Cuándo empieza la gente a comprar?** </font>

# %%
# Para saber cuando empieza la gente a comprar, necesitamos agregar la columna de mes de inicio de sesión en el primer DataFrame
visits_df['month_session'] = visits_df['start_ts'].astype('datetime64[M]')

# Teniendo esto, ahora agregaremos la columna del mes de pedido en el segundo DataFrame
orders_df['order_month'] = orders_df['buy_ts'].astype('datetime64[M]')

# %%
# Teniendo esta información, ya podemos buscar la primera sesión de cada usuario
first_session_dates = visits_df.groupby('uid')['month_session'].min().reset_index()

# Cambiamos el nombre de la columna
first_session_dates.columns = ['uid', 'first_session_month']

# Comprobamos si se aplicaron correctamente los cambios
first_session_dates.head()
# Out:
#                uid first_session_month
# 0   11863502262781          2018-03-01
# 1   49537067089222          2018-02-01
# 2   68042923879230          2017-10-01
# 3  122254899959089          2017-12-01
# 4  187667010442558          2018-01-01

# %%
# Ya que tenemos esta columna, podemos unirla al primer DataFrame con el metodo de "merge"
visits_log_us_ = visits_df.merge(first_session_dates, on= 'uid')
visits_log_us_.head(5)
# Out:
#     device              end_ts  source_id            start_ts  \
# 0    touch 2017-12-20 17:38:00          4 2017-12-20 17:20:00
# 1  desktop 2018-02-19 17:21:00          2 2018-02-19 16:53:00
# 2    touch 2017-07-01 01:54:00          5 2017-07-01 01:54:00
# 3  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 4  desktop 2018-03-09 20:33:00          4 2018-03-09 20:05:00
#
#                    uid  session_year  session_month  session_week  \
# 0  1567487796173571554          2017             12            51
# 1   104060357244891740          2018              2             8
# 2  7459035603376831527          2017              7            26
# 3  2272063814375341402          2018              5            20
# 4  2272063814375341402          2018              3            10
#
#   session_date  session_duration_sec month_session first_session_month
# 0   2017-12-20                  1080    2017-12-01          2017-12-01
# ...

# %%
# Teniendo esta información, ya podemos buscar la fecha para la primera orden que realizo cada usuario.
first_buy_dates = orders_df.groupby('uid')['order_month'].min().reset_index()

# De nuevo, actualizamos el nombre de la columna 
first_buy_dates.columns = ['uid', 'first_buy_month']

# Comprobamos que se hayan realizado correctamente los cambios
first_buy_dates.head()
# Out:
#                 uid first_buy_month
# 0   313578113262317      2018-01-01
# 1   577006494733710      2017-10-01
# 2   587863483079904      2018-02-01
# 3  1142920977281457      2018-03-01
# 4  1336537795138412      2017-09-01

# %%
# Unimos esta columna a nuestro segundo DataFrame con el metodo de "merge"
orders_log_us_ = orders_df.merge(first_buy_dates, on= 'uid')
orders_log_us_.head(5)
# Out:
#                buy_ts  revenue                  uid order_month  \
# 0 2017-06-01 00:10:00    17.00  8117441949118824122  2017-06-01
# 1 2017-06-01 00:25:00     0.55  6819486350016644169  2017-06-01
# 2 2017-06-01 00:27:00     0.37   543063512405337772  2017-06-01
# 3 2017-06-01 00:29:00     0.55  2337504304266998611  2017-06-01
# 4 2017-06-01 07:58:00     0.37  4246138198461172166  2017-06-01
#
#   first_buy_month
# 0      2017-06-01
# 1      2017-06-01
# 2      2017-06-01
# 3      2017-06-01
# 4      2017-06-01

# %%
# Juntamos los dos DataFrames "visits_log_us" y "orders_log_us" en uno solo
visits_orders = visits_log_us_.merge(orders_log_us_, on= 'uid')
visits_orders.head(5)
# Out:
#     device              end_ts  source_id            start_ts  \
# 0  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 1  desktop 2018-03-09 20:33:00          4 2018-03-09 20:05:00
# 2  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
# 3  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
# 4  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
#
#                    uid  session_year  session_month  session_week  \
# 0  2272063814375341402          2018              5            20
# 1  2272063814375341402          2018              3            10
# 2  2439207879601176229          2017              9            35
# 3  2439207879601176229          2017              9            35
# 4  2439207879601176229          2017              9            35
#
#   session_date  session_duration_sec month_session first_session_month  \
# 0   2018-05-20                  1440    2018-05-01          2018-03-01
# ...

# %%
# En este nuevo DataFrame, calculamos los dias transcurridos para cuando un usuario se convierte en cliente
visits_orders['convertion_time_days'] = (visits_orders['first_buy_month'] - visits_orders['first_session_month']).dt.days
visits_orders.head(5)
# Out:
#     device              end_ts  source_id            start_ts  \
# 0  desktop 2018-05-20 11:23:00          9 2018-05-20 10:59:00
# 1  desktop 2018-03-09 20:33:00          4 2018-03-09 20:05:00
# 2  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
# 3  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
# 4  desktop 2017-09-03 21:36:00          5 2017-09-03 21:35:00
#
#                    uid  session_year  session_month  session_week  \
# 0  2272063814375341402          2018              5            20
# 1  2272063814375341402          2018              3            10
# 2  2439207879601176229          2017              9            35
# 3  2439207879601176229          2017              9            35
# 4  2439207879601176229          2017              9            35
#
#   session_date  session_duration_sec month_session first_session_month  \
# 0   2018-05-20                  1440    2018-05-01          2018-03-01
# ...

# %%
# Empezamos a categorizar el tiempo de conversión

# Definimos los intervalos que debe de tener
bins = [-1, 0, 1, 7, 30, 60, 90, 120, 150, 180, 210, 240, 270, 300, 330, 360]
labels = ['Conversion 0d', 'Conversion 1d', 'Conversion 1w', 'Conversion 1m', 'Conversion 2m', 'Conversion 3m', 'Conversion 4m', 'Conversion 5m', 'Conversion 6m', 'Conversion 7m', 'Conversion 8m', 'Conversion 9m', 'Conversion 10m', 'Conversion 11m', 'Conversion 12m']
visits_orders['conversion_category'] = pd.cut(visits_orders['convertion_time_days'], bins=bins, labels=labels)

# Imprimimos las filas
visits_orders.sample(5)
# Out:
#          device              end_ts  source_id            start_ts  \
# 140693  desktop 2017-12-02 10:37:00          2 2017-12-02 10:19:00
# 318516  desktop 2017-12-20 00:30:00          2 2017-12-20 00:27:00
# 52918   desktop 2017-08-26 17:26:00          1 2017-08-26 17:08:00
# 306974  desktop 2017-07-08 14:34:00          5 2017-07-08 14:08:00
# 515587  desktop 2018-01-29 22:41:00          2 2018-01-29 21:16:00
#
#                         uid  session_year  session_month  session_week  \
# 140693  5666701531339072123          2017             12            48
# 318516  5539673724080479777          2017             12            51
# 52918   3263486045884611639          2017              8            34
# 306974  4470812016992341480          2017              7            27
# 515587  8709103738524063405          2018              1             5
#
#        session_date  session_duration_sec month_session first_session_month  \
# ...

# %%
# Ya que tenemos nuestra información filtrada, podemos crear una tabla dinamica para saber la cantidad de pedidos que hicieron los usuarios por Cohorte
first_session_cohort = visits_orders.pivot_table(index= 'first_session_month',
                                       columns= 'conversion_category',
                                       values= 'uid',
                                       aggfunc= 'nunique')

# %%
# Una vez obtenida nuestra tabla dinamica, podemos graficar un mapa de calor para que nos muestre la información más clara y precisa.
plt.figure(figsize=(18, 9))

sns.heatmap(first_session_cohort, annot=True, fmt='g', cmap="crest", linewidths= 1, linecolor='black')

plt.title('Cantidad de usuarios por primer pedido', fontsize= 16)
plt.xlabel('Categoría por conversión', fontsize= 14)


plt.show()

# %%
# A continuación realizamos una suma total por categoria de conversión
first_session_cohort.sum(axis=0)
# Out:
# conversion_category
# Conversion 0d     30073
# Conversion 1d         0
# Conversion 1w         0
# Conversion 1m      1158
# Conversion 2m      1317
# Conversion 3m      1135
# Conversion 4m       792
# Conversion 5m       476
# Conversion 6m       513
# Conversion 7m       370
# Conversion 8m       259
# Conversion 9m       181
# Conversion 10m      122
# Conversion 11m       59
# Conversion 12m       54
# dtype: int64

# %%
# Ahora que los Cohores se definen por el periodo de tiempo de conversión vamos a crear una tabla dinámica para calcular la cantidad de pedidos que se hicieron
convertion_time_cohort = visits_orders.pivot_table(index= 'conversion_category',
                             columns= 'source_id',
                             values= 'uid',
                             aggfunc= 'nunique')

# %%
# Una vez obtenida la tabla dinámica, ya podemos graficar un mapa de calor
plt.figure(figsize=(18, 9))

sns.heatmap(convertion_time_cohort, annot=True, fmt='g', cmap="crest",  linewidths= 1, linecolor='black')

plt.title('', fontsize= 16)
plt.xlabel('Fuente de anuncios del que proviene el usuario', fontsize= 14)


plt.show()

# %%
# Por ultimo, realizamos la suma total de la fuente de anuncios que genera mayores usuarios.
convertion_time_cohort.sum(axis=0)
# Out:
# source_id
# 1      7133
# 2      7302
# 3     13839
# 4     14250
# 5     10154
# 7         1
# 9      2792
# 10     1770
# dtype: int64

# %% [markdown]
# Como podemos observar, en su gran mayoria los usuarios compran en el primer dia que utilizan el servicio. Son 30,073 usuarios que compran desde su primera visita y alrededor de 3000 usuarios realizan su compra luego, despues de 1 a 3 meses de haber visitado el servicio.
#
# Tambien se analizaron las fuentes de donde provienen los diferentes clientes para determinar cuandoes vienen siendo las más efectivas. Y pudimos notal que las fuentes 3,4 y 5 son las que estan generando las mayores cantidades de usuarios de 10,000 a 14,000. Mientras que las fuentes 9 y 10 son las más bajas, ya que estan generando de 1700 a 2900 usuarios.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente análisis para determinar el tiempo de conversión y las fuentes más efectivas. El uso de tablas dinámicas y mapas de calor permite visualizar claramente el comportamiento de los usuarios y las tendencias de conversión por fuente.
#
# </div>

# %% [markdown]
# <font size="4"> **¿Cuántos pedidos hacen durante un período de tiempo dado?** </font>

# %%
# Para responder esta pregunta, necesitamos agrupar los datos de "order_month" y aplicarles el parametro "count"
order_per_month= orders_log_us_.groupby(['order_month'])['uid'].agg(['count', 'nunique']).reset_index()

# Actualizamos los nombres de las columnas
order_per_month.columns= ['order_month', 'n_order', 'n_users']

# Comprobamos que se hayan aplicado correctamente los cambios
order_per_month
# Out:
#    order_month  n_order  n_users
# 0   2017-06-01     2353     2022
# 1   2017-07-01     2362     1983
# 2   2017-08-01     1803     1471
# 3   2017-09-01     3383     2748
# 4   2017-10-01     5677     4673
# 5   2017-11-01     5644     4543
# 6   2017-12-01     6206     4937
# 7   2018-01-01     4721     3898
# 8   2018-02-01     5280     4258
# 9   2018-03-01     5325     4181
# 10  2018-04-01     3265     2742
# 11  2018-05-01     4344     3542
# 12  2018-06-01        1        1

# %%
# Teniendo esta información, ya podemos calcular la cantidad de ordenes que se realizan mensualmente por los usuarios
order_per_month['order_per_user']= order_per_month['n_order'] / order_per_month['n_users']

# Imprimimos el resultado
order_per_month
# Out:
#    order_month  n_order  n_users  order_per_user
# 0   2017-06-01     2353     2022        1.163699
# 1   2017-07-01     2362     1983        1.191125
# 2   2017-08-01     1803     1471        1.225697
# 3   2017-09-01     3383     2748        1.231077
# 4   2017-10-01     5677     4673        1.214851
# 5   2017-11-01     5644     4543        1.242351
# 6   2017-12-01     6206     4937        1.257039
# 7   2018-01-01     4721     3898        1.211134
# 8   2018-02-01     5280     4258        1.240019
# 9   2018-03-01     5325     4181        1.273619
# 10  2018-04-01     3265     2742        1.190737
# 11  2018-05-01     4344     3542        1.226426
# 12  2018-06-01        1        1        1.000000

# %%
# Teniendo estos datos, vamos a crear una grafica para ver los pedidos mensuales efectuados en cada compra.
order_per_month.plot(x = 'order_month',
                  y= 'n_order',
                  kind= 'line',
                  figsize= [12,8],
                  fontsize= 12,
                  rot= 90,
                  color= 'blue'
                       )
plt.title('Pedidos de los usuarios mensuales', fontsize=15)
plt.xlabel('Mes del pedido', fontsize=15)
plt.ylabel('Cantidad total de pedidos', fontsize=15)


plt.show()

# %% [markdown]
# Como podemos observar, graficamos la cantidad de pedidos realizados por los usuarios mensualmente y podemos notar que las mejores ventas se realizaron a partir de Octubre 2017 hasta Marzo del 2018. Esto debido a que es la temporada de festividades más comun en todo el mundo.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen enfoque al calcular y visualizar la cantidad de pedidos mensuales por usuario. La identificación de picos en temporadas festivas es un análisis clave para comprender patrones de compra y planificar estrategias comerciales.
#
# </div>

# %% [markdown]
# <font size="4"> **¿Cuál es el tamaño promedio de compra?** </font>

# %%
# Para calcular el promedio, necesitamos aplicar las diferentes formulas en nuestras columnas de pedidos por usuarios
total_orders_mean = order_per_month['n_order'].mean().round()
orders_per_user_mean = order_per_month['order_per_user'].mean().round()
print(f'El promedio de pedidos mensuales es de {total_orders_mean}')
print(f'Los pedidos en promedio que se hacen por cada usuario mensual son de {orders_per_user_mean}')
# Out:
# El promedio de pedidos mensuales es de 3874.0
# Los pedidos en promedio que se hacen por cada usuario mensual son de 1.0

# %% [markdown]
# Como podemos observar contamos con un promedio de 3874 de pedidos mensuales y 1 pedido promedio mensual que realiza cada usuario.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen trabajo al calcular el promedio de pedidos mensuales y por usuario. Estas métricas brindan una visión clara del comportamiento general de compra en el período analizado.
#
# </div>

# %% [markdown]
# <font size="4"> **¿Cuánto dinero traen? (LTV)** </font>

# %%
# Creamos el Cohorte para buscar dinero que traen los diferentes usuarios
cohort_sizes = orders_log_us_.groupby('first_buy_month').agg({'uid': 'nunique'}).reset_index()

# Actualizamos el nombre de las columnas
cohort_sizes.columns = ['first_buy_month', 'n_buyers']

# Imprimimos resultados
cohort_sizes.head()
# Out:
#   first_buy_month  n_buyers
# 0      2017-06-01      2022
# 1      2017-07-01      1922
# 2      2017-08-01      1369
# 3      2017-09-01      2579
# 4      2017-10-01      4340

# %%
# Ahora, agrupamos la información la orden del mes
cohorts = orders_log_us_.groupby(['first_buy_month','order_month']).agg({'revenue': 'sum'}).reset_index()
cohorts.head()
# Out:
#   first_buy_month order_month  revenue
# 0      2017-06-01  2017-06-01  9557.49
# 1      2017-06-01  2017-07-01   981.82
# 2      2017-06-01  2017-08-01   885.34
# 3      2017-06-01  2017-09-01  1931.30
# 4      2017-06-01  2017-10-01  2068.58

# %%
# Creamos un reporte en donde unimos los dos cohortes en la columna de "first_buy_month"
report = pd.merge(cohort_sizes, cohorts, on='first_buy_month')
report.head()
# Out:
#   first_buy_month  n_buyers order_month  revenue
# 0      2017-06-01      2022  2017-06-01  9557.49
# 1      2017-06-01      2022  2017-07-01   981.82
# 2      2017-06-01      2022  2017-08-01   885.34
# 3      2017-06-01      2022  2017-09-01  1931.30
# 4      2017-06-01      2022  2017-10-01  2068.58

# %%
# Una vez obtenido nuestro reporte, ya podemos calcular el LTV
report['age'] = (
    report['order_month'] - report['first_buy_month']
) / np.timedelta64(1, 'M')
report['age'] = report['age'].round().astype('int')

report['ltv'] = report['revenue'] / report['n_buyers']

report.head()
# Out:
#   first_buy_month  n_buyers order_month  revenue  age       ltv
# 0      2017-06-01      2022  2017-06-01  9557.49    0  4.726751
# 1      2017-06-01      2022  2017-07-01   981.82    1  0.485569
# 2      2017-06-01      2022  2017-08-01   885.34    2  0.437854
# 3      2017-06-01      2022  2017-09-01  1931.30    3  0.955143
# 4      2017-06-01      2022  2017-10-01  2068.58    4  1.023037

# %%
# Creamos una tabla dinamica con los resultados del reporte
output = report.pivot_table(
    index='first_buy_month', columns='age', values='ltv', aggfunc='mean'
)

output.fillna('')
# Out:
# age                    0         1         2         3         4         5   \
# first_buy_month
# 2017-06-01       4.726751  0.485569  0.437854  0.955143  1.023037  0.735865
# 2017-07-01       6.013345  0.335385  0.623855  0.359162  0.176883  0.156129
# 2017-08-01       5.280373  0.472337  0.458817  0.391563  0.494412  0.283747
# 2017-09-01       5.648907  1.118453  0.519938  3.978876  0.400869  0.647569
# 2017-10-01       5.003733  0.535763  0.191394  0.157145   0.15156  0.120362
# 2017-11-01       5.159358  0.398808  0.199703  0.325191  0.147903  0.053919
# 2017-12-01       4.742434  0.260553  0.925731  1.066005  0.313144  0.338279
# 2018-01-01       4.135636  0.294758  0.304281  0.142778  0.062698
# 2018-02-01       4.156987  0.278274  0.078515  0.074144
# 2018-03-01       4.837685  0.300806   0.31547
# 2018-04-01       4.661693  0.532067
# 2018-05-01       4.663684
# 2018-06-01       3.420000
#
# age                    6         7         8         9         10        11
# ...

# %%
# Una vez obtenida la tabla, podemos graficarlos con un mapa de calor para tener una información más clara y precisa
plt.figure(figsize=(18, 9))

sns.heatmap(output, annot=True, fmt='.2f', cmap="crest",  linewidths= 1, linecolor='black')

plt.title('LTV promedio de los clientes.', fontsize= 16)
plt.xlabel('Edad de los cohortes', fontsize= 14)


plt.show()

# %%
# Por ultimo, realizamos la suma total de los ingresos obtenidos por los usuarios en los diferentes meses.
output.sum(axis=1).round()
# Out:
# first_buy_month
# 2017-06-01    12.0
# 2017-07-01     8.0
# 2017-08-01     8.0
# 2017-09-01    13.0
# 2017-10-01     6.0
# 2017-11-01     6.0
# 2017-12-01     8.0
# 2018-01-01     5.0
# 2018-02-01     5.0
# 2018-03-01     5.0
# 2018-04-01     5.0
# 2018-05-01     5.0
# 2018-06-01     3.0
# dtype: float64

# %% [markdown]
# Como podemos observar, podemos apreciar que se generan ingresos desde la edad del cohorte 0, lo cual nos indica que existe una gran cantidad de usuarios que realizar su primera compra el primer momento en que se registran en el servicio. Ademas, se mantiene un estandar de entre 6 y 8 a finales del año 2017 e inicios del 2018 hasta llegar a Junio que hay un bajor de 3.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente implementación del cálculo de LTV mediante cohortes y su representación en un mapa de calor. Este enfoque permite entender claramente la contribución económica de los usuarios a lo largo del tiempo y destaca tendencias clave.
#
# </div>

# %% [markdown]
# # <a id='toc10_'></a>[Marketing](#toc10_)

# %% [markdown]
# En esta sección se nos pide responder correctamente las siguientes preguntas:
# - ¿Cuánto dinero se gastó?  (Total/por fuente de adquisición/a lo largo del tiempo)
# - ¿Cuál fue el costo de adquisición de clientes de cada una de las fuentes?
# - ¿Cuán rentables eran las inversiones? (ROMI)

# %%
# Aqui tenemos nuestro DataFrame de costos de Marketing
costs_df.head(10)
# Out:
#    source_id         dt  costs
# 0          1 2017-06-01  75.20
# 1          1 2017-06-02  62.25
# 2          1 2017-06-03  36.53
# 3          1 2017-06-04  55.00
# 4          1 2017-06-05  57.08
# 5          1 2017-06-06  40.39
# 6          1 2017-06-07  40.59
# 7          1 2017-06-08  56.63
# 8          1 2017-06-09  40.16
# 9          1 2017-06-10  43.24

# %% [markdown]
# <font size="4"> **¿Cuánto dinero se gastó?  (Total/por fuente de adquisición/a lo largo del tiempo)** </font>

# %%
# Vamos a generar un nuevo reporte en donde juntemos la información obtenida del ultimo reporte y la del DataFrame de costos de Marketing
report_marketing = pd.merge(report, costs_df, left_on='order_month', right_on='dt')
report_marketing['cac'] = report_marketing['costs'] / report_marketing['n_buyers']
report_marketing.head()
# Out:
#   first_buy_month  n_buyers order_month  revenue  age       ltv  source_id  \
# 0      2017-06-01      2022  2017-06-01  9557.49    0  4.726751          1
# 1      2017-06-01      2022  2017-06-01  9557.49    0  4.726751          2
# 2      2017-06-01      2022  2017-06-01  9557.49    0  4.726751          3
# 3      2017-06-01      2022  2017-06-01  9557.49    0  4.726751          4
# 4      2017-06-01      2022  2017-06-01  9557.49    0  4.726751          5
#
#           dt   costs       cac
# 0 2017-06-01   75.20  0.037191
# 1 2017-06-01  132.56  0.065559
# 2 2017-06-01  349.38  0.172789
# 3 2017-06-01   76.74  0.037953
# 4 2017-06-01   73.24  0.036222

# %%
# Agruparemos el total de los costos de marketing a lo largo del tiempo
source_costs = report_marketing.groupby('dt')['costs'].sum().sort_values(ascending= False)
source_costs
# Out:
# dt
# 2018-03-01    14372.80
# 2018-02-01    12408.84
# 2017-12-01     7435.05
# 2017-11-01     7418.46
# 2018-05-01     7164.72
# 2018-01-01     6868.72
# 2017-10-01     5186.20
# 2017-09-01     2155.04
# 2017-08-01     1526.97
# 2017-07-01      756.08
# 2017-06-01      735.26
# Name: costs, dtype: float64

# %%
# Una vez obtenidos estos datos, vamops a crear un grafico de los costos totales a lo largo de los meses
source_costs.plot(
                  kind= 'line',
                  figsize= [12,8],
                  fontsize= 12,
                  color= 'green'
                       )
plt.title('Costos totales a lo largo de los meses', fontsize=15)
plt.xlabel('Fecha', fontsize=15)
plt.ylabel('Cantidad total de costos', fontsize=15)

plt.show()

# %% [markdown]
# Como podemos observar, los meses en donde se registraron los mayores costos fuern en Febrero de 2018 (Total: 12,409) y en Marzo del 2018 (Total: 14,373), luego en los proximos meses se reducieron los costos.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente análisis del gasto total y mensual en marketing. La integración del reporte con los costos y su visualización temporal proporcionan una perspectiva clara de los meses con mayor inversión y sus tendencias.
#
# </div>

# %% [markdown]
# <font size="4"> **¿Cuál fue el costo de adquisición de clientes de cada una de las fuentes?** </font>

# %%
# Para calcular lo que se nos pide, necesitamos agrupar la suma del costo de adquisición por la fuente del anuncio
cac_by_source = report_marketing.groupby('source_id')['cac'].sum()
cac_by_source
# Out:
# source_id
# 1      1.669532
# 2      3.520368
# 3     12.475347
# 4      3.716047
# 5      4.504085
# 9      0.512617
# 10     0.435294
# Name: cac, dtype: float64

# %%
# Una vez obtenidos los resultados, ya podemos graficarlos. Utilizaremos una grafica de barras para mostrar la información más clara
cac_by_source.plot(
                  kind= 'bar',
                  figsize= [10,6],
                  fontsize= 12,
                  rot= 0,
                  color= 'blue'
                       )
plt.title('Costo de Adquisición por Fuente del Anuncio', fontsize=15)
plt.xlabel('Fuente del anuncio', fontsize=15)
plt.ylabel('Costo de adquisición', fontsize=15)

plt.show()

# %% [markdown]
# Como podemos observar las fuentes numero 3 y 5 son las principales generadoras de clientes. La cual se destaca por mucho la 3, ya que esta por encima de las demas. Lo cual llama mucho la atención por que en análisis previos nos daba como resultado que la fuente 4 se considera la más efectiva tanto por su rentabilidad como por su capacidad de atracción. Necesitariamos realizar un análisis más profundo para detallar que fuente de anuncio tiene un mayor beneficio en la empresa.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Muy buen cálculo y visualización del costo de adquisición por fuente. Identificar las principales generadoras de clientes como las fuentes 3 y 5 es clave, y el análisis destaca áreas interesantes para profundizar y optimizar estrategias.
#
# </div>

# %% [markdown]
# <font size="4"> **¿Cuán rentables eran las inversiones? (ROMI)** </font>

# %%
# Aplicamos la formula correspondiente para calcular el ROMI
report_marketing['romi'] = report_marketing['ltv'] / report_marketing['cac']

# Creamos una tabla dinamica con los resultados obtenidos e imprimimos el resultado
output2 = report_marketing.pivot_table(
    index='first_buy_month', columns='age', values='romi', aggfunc='mean'
).round()

output2.fillna('')
# Out:
# age                 0     1      2      3     4     5     6     7     8   \
# first_buy_month
# 2017-06-01       264.0  64.0   39.0   80.0  62.0  28.0  42.0  19.0  29.0
# 2017-07-01       754.0  29.0   50.0   21.0   6.0   7.0   4.0   7.0   9.0
# 2017-08-01       320.0  27.0   19.0   10.0  15.0   6.0   7.0  17.0
# 2017-09-01       602.0  86.0   25.0  223.0  17.0  43.0  55.0        21.0
# 2017-10-01       649.0  44.0   18.0   11.0  17.0  16.0        22.0
# 2017-11-01       400.0  35.0   13.0   34.0  18.0        20.0
# 2017-12-01       451.0  18.0  105.0  141.0        64.0
# 2018-01-01       224.0  26.0   31.0          9.0
# 2018-02-01       392.0  31.0          12.0
# 2018-03-01       518.0         48.0
# 2018-04-01              53.0
# 2018-05-01       606.0
#
# age                9     10    11
# first_buy_month
# 2017-06-01       37.0        23.0
# 2017-07-01             13.0
# 2017-08-01       11.0
# 2017-09-01
# 2017-10-01
# 2017-11-01
# 2017-12-01
# 2018-01-01
# 2018-02-01
# ...

# %%
# Una vez obtenido los resultados, vamos a graficar un mapa de calor para mostrar los resultados de una mejor manera
plt.figure(figsize=(16, 9))

sns.heatmap(output2, annot=True, fmt='0.0f', cmap="crest",  linewidths= 1, linecolor='black')

plt.title('Rentabilidad de las inversiones (ROMI).', fontsize= 16)
plt.xlabel('Edad de las cohortes', fontsize= 14)


plt.show()

# %%
# Ahora vamos a crear otra tabla dinamica en donde sea la suma acumulativa por cohorte de las inversiones
output3 = report_marketing.pivot_table(
    index='first_buy_month', columns='age', values='romi', aggfunc='mean'
).round().cumsum(axis=1)


output3.fillna('')
# Out:
# age                 0      1      2      3      4      5       6      7   \
# first_buy_month
# 2017-06-01       264.0  328.0  367.0  447.0  509.0  537.0   579.0  598.0
# 2017-07-01       754.0  783.0  833.0  854.0  860.0  867.0   871.0  878.0
# 2017-08-01       320.0  347.0  366.0  376.0  391.0  397.0   404.0  421.0
# 2017-09-01       602.0  688.0  713.0  936.0  953.0  996.0  1051.0
# 2017-10-01       649.0  693.0  711.0  722.0  739.0  755.0          777.0
# 2017-11-01       400.0  435.0  448.0  482.0  500.0          520.0
# 2017-12-01       451.0  469.0  574.0  715.0         779.0
# 2018-01-01       224.0  250.0  281.0         290.0
# 2018-02-01       392.0  423.0         435.0
# 2018-03-01       518.0         566.0
# 2018-04-01               53.0
# 2018-05-01       606.0
#
# age                  8      9      10     11
# first_buy_month
# 2017-06-01        627.0  664.0         687.0
# 2017-07-01        887.0         900.0
# 2017-08-01               432.0
# 2017-09-01       1072.0
# ...

# %%
# De nuevo la graficamos en un mapa de calor
plt.figure(figsize=(16, 9))

sns.heatmap(output3, annot=True, fmt='.1f', cmap="crest",  linewidths= 1, linecolor='blue')

plt.title('Rentabilidad acumulativa por cohorte de las inversiones (ROMI)', fontsize= 16)
plt.xlabel('Edad de las cohortes', fontsize= 14)


plt.show()

# %%
# Realizamos la suma total de output3
output3.cumsum(axis=1).mean(axis=0).round()
# Out:
# age
# 0      471.0
# 1      852.0
# 2     1448.0
# 3     2122.0
# 4     2645.0
# 5     3624.0
# 6     4036.0
# 7     4599.0
# 8     6285.0
# 9     4187.0
# 10    8487.0
# 11    5607.0
# dtype: float64

# %%
# Ahora descubriremos cual es la plataforma favorita utilizada por los usuarios
favorite_platform= visits_df['device'].value_counts().reset_index()
favorite_platform.columns= ['platform', 'count']
favorite_platform['%']= ((favorite_platform['count'] * 100) / 359400).round() 
favorite_platform
# Out:
#   platform   count     %
# 0  desktop  262567  73.0
# 1    touch   96833  27.0

# %%
# Realizamos una grafica para destacar cual es la plataforma favorita de los usuarios
favorite_platform.plot(
                  kind= 'bar',
                  x= 'platform',
                  figsize= [10,6],
                  fontsize= 12,
                  rot= 0,
                  color= 'green',
                  legend= False
                       )
plt.title('Plataforma favorita por los usuarios', fontsize=15)
plt.xlabel('Plataformas', fontsize=15)
plt.ylabel('Cantidad de visitas', fontsize=15)

plt.show()

# %% [markdown]
# Como pudimos observar, en el análisis de los cohortes pudimos revelar que el costo de adquisición de cada usuario se recupera rapidamente, de tal manera que se genera un beneficio promedio entre 400 y 900 mensuales. Lo cual nos da un resultado muy psoitivo.
#
# Y en la grafica de dispotivos más utilizados, podemos observar que hay una clara preferencia por utilizar equipos de computo de escritorio con un total del 73% de usuarios mientras que los dispositivos moviles representan solol el 27% restante. Aqui puede ser un punto clave optimización en las plataformas moviles para que puedan llamar la atención de los usuarios y quieran utilizar los servicios en dicha plataforma.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente análisis del ROMI y su rentabilidad acumulativa. El uso de cohortes y mapas de calor resalta la recuperación rápida del costo de adquisición y los beneficios consistentes. Además, la identificación de la preferencia por dispositivos de escritorio brinda una valiosa oportunidad para optimizar la experiencia móvil.
#
# </div>

# %% [markdown]
# # <a id='toc11_'></a>[Conclusiones Finales](#toc11_)

# %% [markdown]
# En conclusión, nos topamos con 3 Dataframes muy completos los cuales contenian la información relavante que necesitabamos para poder contestar las preguntas establecidas por los dueños de la empresa.
#
# Al principio se detecto que los DataFrames no cumplian con los parametros que necesitaban tener los datos para poder realizar un análisis profundo en ellos. Asi que aplicamos los metodos correctos para corregir mayusculas, valores atipicos, espacios, entre otras cosas.
#
# Ya una vez realizado el análisis detectamos que:
#
# **VISITAS:**
# - Cuenta con un buen numero de usuarios activos diarios: 908 en total, semanales: 5716 y mensuales: 23,228.
# - El promerio de numero de sesiones por usuario por dia es 1 (Lo cual es bueno ya que diariamente se conecta alguien).
# - La duración de cada sesión es de 1 minuto.
# - Cuentan con una frecuencia del 16% de usuarios que usan el servicio en una semana tambien la usan diariamente y del 4% de los usuarios que la usan en un mes tambien la usan diariamente.
#
# **VENTAS:**
# - Tenemos el dato que por lo menos 30,073 usuarios realizaron una compra en su primera visita mientras que el resto de usuarios alrededor de 3000 realizaron su compra despues en un promedio de 1 a 3 meses.
# - Se registraron más de 5000 mil pedidos realizados entre Octubre 2017 a Marzo del 2018 (En temporada de festividades)
# - El promedio de pedidos que se hacen mensual es de 3874 y los pedidos en promedio que se hace por usuario mensual es de 1
# - Se registro que a partir de Septiembre del 2017 se generaron buenos ingresos y asi se mantuvo hasta Junio 2018.
#
# **Marketing:**
# - Los meses en donde más se gasto en Marketing fueron Febrero 2018 (Con 12,409) y Marzo 2018 (Con 14,373).
# - La fuente de anuncio numero 3 y 5 fueron las que trajeron más clientes.
#
# Y por ultimo, me gustaria añadir que la plataforma más usada y preferida de los usuarios es el equipo de computo de escritorio.

# %% [markdown]
# <font size="5"> **Recomendaciones** </font>

# %% [markdown]
# Me gustaria agregar algunas recomendaciónes para el equipo de Showz que pude detectar que pueden implementar en base a este análisis realizado:
#
# **Optimización para Dispositivos Móviles:**
# - Aunque las computadoras de escritorio dominan con un 73% del tráfico, recomiendo invertir en mejorar la experiencia móvil para capturar una mayor parte del 27% del tráfico móvil.
#
# - Se pueden desarrollar estrategias específicas para aumentar las conversiones en dispositivos móviles ya que este no se encuentra en un porcentaje bajo y se le puede sacar mucho provecho por la facilidad del usuario que puede utilizarlo.
#
# **Una gestión del ciclo de vida del cliente:**
# - Desarrollar programas de fidelización para aumentar la frecuencia de compra, ya que el promedio actual es de 1 pedido mensual por usuario y este numero puede aumentar.
#
# - Implementar estrategias para aumentar el valor de compra promedio y al lograr esto aumentara tambien el LTV de los clientes.
#
# **Mejora en la experiencia inicial del usuario:**
# - Esto dado que la mayoría de las compras ocurren el primer día de visita, enfócarse en mejorar la experiencia de usuario inicial para aumentar las conversiones. Y de esta manera lograr que más usuarios se interesen en realizar su compra en su primera visita.
#
# - Considerar implementar estrategias de retención para aumentar el porcentaje de usuarios activos diarios, especialmente a largo plazo.
#
# - Implementar alguna membresia que pueda mantener el interes del usuario y pueda darle beneficios positivos a los usuarios sin descuidar a los que no esten interesados en ella.
#
# **Un análisis continuo y monitorear los datos obtenidos:**
# - Establecer un sistema de monitoreo continuo de KPIs clave como DAU, WAU, MAU, tasa de conversión, y ROMI. De esta manera estas al pendiente de los resultados y se pueda realizar una toma de decisiones basada en estos resultados.
#
# - Utilizar estos datos para informar decisiones estratégicas y ajustar las tácticas de marketing y desarrollo de producto.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Muy buena síntesis de conclusiones y recomendaciones prácticas. Has conectado de manera clara los insights obtenidos con estrategias específicas, mostrando un enfoque bien fundamentado para optimizar la experiencia del usuario y las métricas de negocio.
#
# </div>

# %% [markdown]
# # Comentario general del revisor

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades Javier! Tu proyecto está **aprobado**. Has logrado realizar un análisis completo, desde la limpieza inicial de los datos hasta la generación de insights estratégicos y recomendaciones claras. A continuación, destaco los puntos clave y algunas sugerencias para fortalecer futuros análisis:
#
# Puntos Positivos:
# - **Limpieza de datos sólida:** Identificaste y corregiste problemas en los DataFrames, lo cual fue clave para garantizar la calidad del análisis.
# - **Análisis detallado de visitas, ventas y marketing:** Respondiste a todas las preguntas clave utilizando métricas relevantes como DAU, LTV, CAC y ROMI.
# - **Visualización efectiva:** Usaste gráficos y mapas de calor para comunicar los resultados de forma clara y comprensible.
# - **Recomendaciones accionables:** Tus propuestas, como optimizar la experiencia móvil y mejorar la fidelización, son prácticas y alineadas con los hallazgos.
#
# Sugerencias para Futuras Mejoras:
# - **Análisis más profundo de fuentes menos rentables:** Explorar las razones detrás de las fuentes con ROMI bajo podría ayudar a optimizar aún más las inversiones.
# - **Automatización del monitoreo:** Implementar scripts para actualizar automáticamente las métricas clave agilizaría la toma de decisiones.
# - **Exploración avanzada de cohortes:** Ampliar el análisis a cohortes con características adicionales, como canal de adquisición o geografía, podría ofrecer más insights.
#
# Tu trabajo demuestra una excelente comprensión de los datos y un enfoque estratégico para resolver problemas. ¡Sigue así, estás en el camino correcto para sobresalir en el análisis de datos! 🚀😊
#
# </div>
